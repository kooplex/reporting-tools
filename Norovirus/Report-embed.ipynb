# %%
from ipynb.fs.full.Report_tools import *

# %% [markdown]
# ### Title

# %%
show(plot_from_url('https://kooplex-fiek.elte.hu/notebook/wfct0p-rere-wfct0p/report/pie?country_checkbox_pie=all&date_slider_pie=26-08-2014,09-12-2019'))
# Out:
#   <div class="bk-root" id="bd8d6780-58a4-4437-8c46-3251f3395552" data-root-id="2267"></div>

# %% [markdown]
# ### Section 1
# Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eligendi non quis exercitationem culpa nesciunt nihil aut nostrum explicabo reprehenderit optio amet ab temporibus asperiores quasi cupiditate. Voluptatum ducimus voluptates voluptas?

# %%
show(plot_from_url('https://kooplex-fiek.elte.hu/notebook/wfct0p-rere-wfct0p/report/bar?country_checkbox_bar=all&date_slider_bar=26-08-2018,09-12-2019&genotype_checkbox_bar=Caliciviridae%20Norovirus%20GII'))
# Out:
#   <div class="bk-root" id="3474415f-4d32-427c-9a1a-89c5d0c35c1c" data-root-id="1838"></div>

# %% [markdown]
# ## References
# 1. Yang Y, Li B, Zou S, Fang HHP, Zhang T. 2014. Fate of antibiotic resistance genes in sewage treatment plant revealed by metagenomic approach. Water Res 62:97–106. doi:10.1016/j.watres.2014.05.019. CrossRefGoogle Scholar
# 2. Chen S, Zhou Y, Chen Y, Gu J. 2018. fastp: an ultra-fast all-in-one FASTQ preprocessor. Bioinformatics 34:i884–i890. doi:10.1093/bioinformatics/bty560.
# 3. Wood DE, Lu J, Langmead B. 2019. Improved metagenomic analysis with Kraken 2. Genome Biol 20:257. doi:10.1186/s13059-019-1891-0.
